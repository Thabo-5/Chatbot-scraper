# %%
import io
import re
import time
import requests
#import pdfplumber
import numpy as np
import pandas as pd
import urllib.request
from io import BytesIO
from bs4 import BeautifulSoup

# %%
# Open website home page

URL = 'https://explore-datascience.net/'
page = requests.get(URL)
soup = BeautifulSoup(page.content, 'html.parser')

# Extract all urls from the website page

def get_urls(soup):
    """
    Function returns a list of all url links from a BeautifulSoup object.
    """
    urls = []
    for link in soup.find_all('a'):
        if link.get('href') != None:
            urls.append(link.get('href'))
    urls = [x for x in urls if 'https' in x]
    urls = list(set(urls))
    return urls

urls_list = get_urls(soup)

# %%
def website_links(urls_list):
    urls = [x for x in urls_list if '.pdf' not in x and 'facebook' not in x]
    pdfs = [x for x in urls_list if '.pdf' in x]
    new_urls = []
    for i in range(len(urls)):
        page = requests.get(urls[i])
        soup = BeautifulSoup(page.content, 'html.parser')
        pg_urls = get_urls(soup)
        if len(pg_urls) > 0:
            pdfs.extend([x for x in pg_urls if '.pdf' in x and x not in pdfs])
            new_urls.extend([x for x in pg_urls if x not in urls 
                             and x not in new_urls 
                             and x not in pdfs 
                             and 'https://explore-datascience.net' in x])
    urls.extend(new_urls)
    return urls, len(new_urls), pdfs

# %%
# Extract all urls and pdfs from the website.

urls, new_urls, pdfs = website_links(urls_list)
if new_urls > 0:
    urls, new_urls, pdfs = website_links(urls_list)

# %%
# Scrape text data from the website (this excludes the pdfs)

for j in range(len(urls)):
    page = requests.get(urls[j])
    soup = BeautifulSoup(page.content, 'html.parser')
    a = re.sub(r'/\d$', '', str(urls[j]))
    name = "".join(re.findall(r'[^/]+(?=/$|$)', a))
    f = open("{}.txt".format(name),"a+")
    f.write('{}\n'.format(urls[j]))
    for items in soup.find_all('section'):
        all_text = [item.text for item in items.find_all(['h2', 'h3', 'p', 'li'])]
        headings2 = [item.text for item in items.find_all(['h2'])]
        headings3 = [item.text for item in items.find_all(['h3'])]
        paragraphs = [item.text for item in items.find_all(['p'])]
        if len(all_text) > 0:
            all_text = ['H2: {}'.format(word) if word in headings2 else word for word in all_text]
            all_text = ['H3: {}'.format(word) if word in headings3 else word for word in all_text]
            all_text = ['Paragraph: {}'.format(word) if word in paragraphs else word for word in all_text]
            for i in all_text:
                f.write('{}\n'.format(i))

    faqs = list([item.text for item in soup.find_all('div', class_='accordion-group')])
    for i in range(len(faqs)):
        f.write('FAQ_{0}: {1}'.format(i, faqs[i]))

    for link in soup.select('div[class^="prices"]'):
        f.write('Prices: {}\n'.format(link.text))

    f.close()
    print('Completed {0} of {1}'.format(j+1, len(urls)))
# Out:
# Completed 1 of 52
# Completed 2 of 52
# Completed 3 of 52
# Completed 4 of 52
# Completed 5 of 52
# Completed 6 of 52
# Completed 7 of 52
# Completed 8 of 52
# Completed 9 of 52
# Completed 10 of 52
# Completed 11 of 52
# Completed 12 of 52
# Completed 13 of 52
# Completed 14 of 52
# Completed 15 of 52
# Completed 16 of 52
# Completed 17 of 52
# Completed 18 of 52
# Completed 19 of 52
# Completed 20 of 52
# Completed 21 of 52
# Completed 22 of 52
# Completed 23 of 52
# Completed 24 of 52
# Completed 25 of 52
# Completed 26 of 52
# Completed 27 of 52
# Completed 28 of 52
# Completed 29 of 52
# Completed 30 of 52
# Completed 31 of 52
# Completed 32 of 52
# Completed 33 of 52
# Completed 34 of 52
# Completed 35 of 52
# Completed 36 of 52
# Completed 37 of 52
# Completed 38 of 52
# Completed 39 of 52
# Completed 40 of 52
# Completed 41 of 52
# Completed 42 of 52
# Completed 43 of 52
# Completed 44 of 52
# Completed 45 of 52
# Completed 46 of 52
# Completed 47 of 52
# Completed 48 of 52
# ...

# %%
urls
# Out:
# ['https://explore-datascience.net/long-courses/machine-learning/2',
#  'https://explore-datascience.net/long-courses/software-engineering/1',
#  'https://explore-datascience.net/home/why-us',
#  'https://explore-datascience.net/home/blog',
#  'https://explore-datascience.net/about-us/practice-areas',
#  'https://explore-datascience.net/alumni/hire-explorer',
#  'https://explore-datascience.net/long-courses/software-engineering',
#  'https://explore-datascience.net/long-courses/data-analytics',
#  'https://explore-datascience.net/long-courses/data-engineering/2',
#  'https://explore-datascience.net/short-courses/advanced-visualisation',
#  'https://explore-datascience.net/long-courses/data-science',
#  'https://explore-datascience.net/long-courses/data-engineering/1',
#  'https://explore-datascience.net/enterprise/reskill-teams',
#  'https://explore-datascience.net/about-us/our-explorers',
#  'https://explore-datascience.net/long-courses/software-engineering/2',
# ...
